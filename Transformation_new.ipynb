# %% [markdown]
# #Transformation new
#
# Q1. Handle Missing Values (Basic Cleaning)
#
# Fill missing values using the following:
#
# Age → Median
#
# Salary → Mean
#
# Hours_Worked_Per_Week → Median
#
# Performance_Score → Mean
#
# Display the dataset after handling missing values.
#
# -import pandas as pd
#
# df = pd.read_csv("employee_productivity_dataset.csv")
#
# # Fill missing values
# df['Age'].fillna(df['Age'].median(), inplace=True)
# df['Salary'].fillna(df['Salary'].mean(), inplace=True)
# df['Hours_Worked_Per_Week'].fillna(df['Hours_Worked_Per_Week'].median(), inplace=True)
# df['Performance_Score'].fillna(df['Performance_Score'].mean(), inplace=True)
#
# print(df.head())
#
# Median is used for Age & Hours (robust to outliers)
# Mean is used for Salary & Performance Score
# This step ensures no missing data before ML
#
# Q2. Label Encoding
#
# Convert these columns into numeric values using Label Encoding:
#
# Gender
#
# Department
#
# Show the updated columns.
#
# -  from sklearn.preprocessing import LabelEncoder
#
# le = LabelEncoder()
#
# df['Gender'] = le.fit_transform(df['Gender'])
# df['Department'] = le.fit_transform(df['Department'])
#
# print(df[['Gender', 'Department']].head())
#
# Converts categorical text → numeric labels
# Example: Male = 1, Female = 0
#
# Q3. One-Hot Encoding
#
# Apply One-Hot Encoding on:
#
# Work_Mode
#
# Location
#
# Display the dataset and check how many new columns are created.
#
# - Q3. One-Hot Encoding
#
# Apply One-Hot Encoding on:
#
# Work_Mode
#
# Location
#
# Display the dataset and check how many new columns are created.
#
# Creates binary columns (0/1)
# Prevents ordinal relationship problem
#
# Q4. Normalization (Min-Max Scaling)
#
# Normalize the following columns:
#
# Salary
#
# Hours_Worked_Per_Week
#
# Use MinMaxScaler and display results
#
# - from sklearn.preprocessing import MinMaxScaler
#
# scaler = MinMaxScaler()
#
# df[['Salary', 'Hours_Worked_Per_Week']] = scaler.fit_transform(
#     df[['Salary', 'Hours_Worked_Per_Week']]
# )
#
# print(df[['Salary', 'Hours_Worked_Per_Week']].head())
#
# Scales values between 0 and 1
# Useful when features have different ranges
#
# Q5. Standardization (Scaling)
#
# Apply StandardScaler on:
#
# Age
# rojects_Completed
#
# Display the transformed values.
#
# - from sklearn.preprocessing import StandardScaler
#
# scaler = StandardScaler()
#
# df[['Age', 'Projects_Completed']] = scaler.fit_transform(
#     df[['Age', 'Projects_Completed']]
# )
#
# print(df[['Age', 'Projects_Completed']].head())
#
# Converts data to mean = 0, std = 1
# Helps models like SVM, Logistic Regression
#
# Q6. Compare Scaling Methods
#
# Apply both:
#
# MinMaxScaler
#
# StandardScaler
#
# On the Salary column.
#
# Show both results side by side.
#
# - salary_data = df[['Salary']]
#
# minmax = MinMaxScaler()
# standard = StandardScaler()
#
# salary_minmax = minmax.fit_transform(salary_data)
# salary_standard = standard.fit_transform(salary_data)
#
# comparison = pd.DataFrame({
#     'Original': salary_data['Salary'],
#     'MinMax': salary_minmax.flatten(),
#     'Standardized': salary_standard.flatten()
# })
#
# print(comparison.head())
#
# Explanation:
# MinMax → range (0–1)
# StandardScaler → centered distribution
#
# Q7. Build Preprocessing Pipeline
#
# Create a pipeline that:
#
# Applies encoding to categorical columns
#
# Applies scaling to numerical columns
#
# Use:
#
# ColumnTransformer
#
# Pipeline
#
# from sklearn.pipeline import Pipeline
# from sklearn.compose import ColumnTransformer
#
# num_cols = ['Age', 'Salary', 'Hours_Worked_Per_Week', 'Projects_Completed']
# cat_cols = ['Gender', 'Department', 'Work_Mode', 'Location']
#
# from sklearn.preprocessing import OneHotEncoder
#
# preprocessor = ColumnTransformer([
#     ('num', StandardScaler(), num_cols),
#     ('cat', OneHotEncoder(), cat_cols)
# ])
#
# pipeline = Pipeline([
#     ('preprocessing', preprocessor)
# ])
#
# Explanation:
# Combines all preprocessing steps
# Ensures consistent transformation
#
# Q8. Apply Pipeline
#
# Apply the pipeline on the dataset.
#
# Display:
#
# Transformed dataset
#
# Shape of final dataset
#
# - X = df.copy()
#
# X_transformed = pipeline.fit_transform(X)
#
# print("Shape of transformed dataset:", X_transformed.shape)
# print(X_transformed[:5])
#
# Explanation:
# Applies all transformations in one step
# Output is a numerical matrix
#
# Q9. Conceptual Question
# Scaling is important because:
#
# Ensures all features contribute equally
# Prevents bias toward large-value features
# Improves model performance and convergence speed
# Required for distance-based algorithms (KNN, SVM)
#
# Why is scaling important in Python?
#
# Q10. Conceptual Question
#
# Why do we convert categorical data into numerical form?
#
# - Machine learning models cannot understand text data. Therefore:
#
# Categorical values must be converted to numbers
# Enables mathematical computations
# Improves model accuracy
# Techniques: Label Encoding, One-Hot Encoding
